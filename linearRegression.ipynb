# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(42)

# %%
X = 2*np.random.rand(100,1)
y = 4+3*X+np.random.randn(100,1)

# %%
plt.scatter(X,y, alpha=0.6)
plt.title("Linear Regression Dataset")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model = LinearRegression()
model.fit(X,y)
X_new = np.linspace(0,2,100).reshape(-1,1)
y_pred = model.predict(X_new)

# %%
plt.scatter(X,y, alpha=0.6, label="Original Data")
plt.plot(X_new, y_pred, color = 'red', label= "Linear Regression")
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()
print(f"slope coefficient:{model.coef_[0][0]}")
print(f"Intercept{model.intercept_[0]}")
# Out:
# slope coefficient:2.872292023783016
# Intercept4.091758888516954
